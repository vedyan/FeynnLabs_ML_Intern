# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('EV_market.csv')
dataset.head()
df=dataset.copy()
df.head()
# Out:
#    Age       City   Profession  Marital Status          Education  \
# 0   29     Mumbai     Engineer          Single            Masters
# 1   45      Delhi  Businessman         Married                PhD
# 2   33  Bangalore       Doctor          Single  Bachelor's degree
# 3   41    Kolkata      Manager         Married                MBA
# 4   37  Hyderabad      Teacher         Married  Bachelor's degree
#
#     No. of Family members   Annual Income  \
# 0                       2          900000
# 1                       4         1500000
# 2                       1          800000
# 3                       3         1800000
# 4                       4         1000000
#
#    Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#    If Yes/Maybe what type of EV would you prefer?  \
# 0                                           Sedan
# 1                                       Hatchback
# 2                                Electric Scooter
# 3                                             NaN
# 4                                       Hatchback
#
#    Do you think Electronic Vehicles are economical?  \
# 0                                               Yes
# 1                                               Yes
# 2                                               Yes
# 3                                               Yes
# 4                                               Yes
#
#    Which brand of vehicle do you currently own?  \
# 0                                         Tesla
# 1                                        Maruti
# 2                                           NaN
# 3                                        Toyota
# 4                                       Hyundai
#
#    How much money could you spend on an Electronic vehicle?  \
# 0                                            2000000
# 1                                            1000000
# 2                                              50000
# 3                                            3000000
# 4                                             600000
#
#    Preference for wheels in EV  \
# 0                            4
# 1                            4
# 2                            2
# 3                            4
# 4                            4
#
#    Do you think Electronic vehicles will replace fuel cars in India?
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes

# %%
df.isnull().sum()
# Out:
# Age                                                                       0
#  City                                                                     0
#  Profession                                                               0
#  Marital Status                                                           0
#  Education                                                                0
#  No. of Family members                                                    0
#  Annual Income                                                            0
#  Would you prefer replacing all your vehicles to Electronic vehicles?     0
#  If Yes/Maybe what type of EV would you prefer?                          19
#  Do you think Electronic Vehicles are economical?                         0
#  Which brand of vehicle do you currently own?                             7
#  How much money could you spend on an Electronic vehicle?                 1
#  Preference for wheels in EV                                              0
#  Do you think Electronic vehicles will replace fuel cars in India?        0
# dtype: int64

# %%
print(df.isna().sum())
# Out:
# Age                                                                       0
#  City                                                                     0
#  Profession                                                               0
#  Marital Status                                                           0
#  Education                                                                0
#  No. of Family members                                                    0
#  Annual Income                                                            0
#  Would you prefer replacing all your vehicles to Electronic vehicles?     0
#  If Yes/Maybe what type of EV would you prefer?                          19
#  Do you think Electronic Vehicles are economical?                         0
#  Which brand of vehicle do you currently own?                             7
#  How much money could you spend on an Electronic vehicle?                 1
#  Preference for wheels in EV                                              0
#  Do you think Electronic vehicles will replace fuel cars in India?        0
# dtype: int64

# %%
print(df.info())
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 14 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Age                                                                    117 non-null    int64
#  1    City                                                                  117 non-null    object
#  2    Profession                                                            117 non-null    object
#  3    Marital Status                                                        117 non-null    object
#  4    Education                                                             117 non-null    object
#  5    No. of Family members                                                 117 non-null    int64
#  6    Annual Income                                                         117 non-null    int64
#  7    Would you prefer replacing all your vehicles to Electronic vehicles?  117 non-null    object
#  8    If Yes/Maybe what type of EV would you prefer?                        98 non-null     object
#  9    Do you think Electronic Vehicles are economical?                      117 non-null    object
#  10   Which brand of vehicle do you currently own?                          110 non-null    object
#  11   How much money could you spend on an Electronic vehicle?              116 non-null    object
#  12   Preference for wheels in EV                                           117 non-null    object
#  13   Do you think Electronic vehicles will replace fuel cars in India?     117 non-null    object
# dtypes: int64(3), object(11)
# memory usage: 12.9+ KB
# None
# Index(['Age', ' City', ' Profession', ' Marital Status', ' Education',
#        ' No. of Family members', ' Annual Income',
#        ' Would you prefer replacing all your vehicles to Electronic vehicles?',
#        ' If Yes/Maybe what type of EV would you prefer?',
#        ' Do you think Electronic Vehicles are economical?',
#        ' Which brand of vehicle do you currently own?',
#        ' How much money could you spend on an Electronic vehicle?',
#        ' Preference for wheels in EV',
#        ' Do you think Electronic vehicles will replace fuel cars in India?'],
#       dtype='object')

# %%
df[' Do you think Electronic vehicles will replace fuel cars in India?'].unique()
# Out:
# array(['Yes', 'No', 'Maybe'], dtype=object)

# %%
df[' Profession'].replace(to_replace=[' Engineer', ' Businessman', ' Doctor', ' Student',
       ' Manager'],value=['Engineer','Businessman','Doctor','Student','Manager'],inplace=True)

# %%
df.replace(to_replace = [' Single', ' Married'], value = ['Single', 'Married'], inplace = True)
df.replace(to_replace = [' 4', ' 2'], value = ['4', '2'], inplace = True)
df.replace(to_replace = ["Masters","Master's Degree","Bachelor's Degree","Bachelor's",'Doctorate'], value = ["Master's degree","Master's degree","Bachelor's degree","Bachelor's degree",'Doctorate degree'], inplace = True)
df.replace(to_replace = [' Yes', ' Maybe', ' No'], value = ['Yes','Maybe','No'], inplace = True)

df.replace(to_replace = [' Hatchback',
       ' Sedan', ' N/A', ' Electric Scooter', ' SUV','-'], value = ['Hatchback','Sedan','N/A','Electric Scooter','SUV','N/A'] , inplace = True)
df.replace(to_replace = [' Maruti', ' Honda', ' Toyota', ' Ford'], value = ['Maruti','Honda','Toyota','Ford'], inplace = True)
df.replace(to_replace = [' 50000', ' 4000000',' 1000000', ' 2000000'], value =['50000', '4000000','1000000', '2000000'], inplace = True)

# %%
df.replace(to_replace = [' Mumbai', ' Bangalore', ' Delhi', ' Kolkata', ' Hyderabad'], value = ['Mumbai', 'Delhi', 'Bangalore', 'Kolkata', 'Hyderabad'], inplace = True)

# %%
df.to_csv('EV_mod.csv')

# %%
dataset=pd.read_csv('EV_mod1.csv')

# %%
df=pd.read_csv('EV_mod1.csv')

# %%
for col in df.columns:
    ax= sns.displot(df[col])
    ax.set_xticklabels(rotation=90)

# %% [markdown]
# Most people prefer 4 wheelers.
# Most people think EV will replace fuel cars in India.

# %%
sns.countplot(x =' Education', hue = ' Would you prefer replacing all your vehicles to Electronic vehicles?',  data = df, palette = 'Set2')
plt.legend(bbox_to_anchor=(1, 0.5))
plt.show()

# %%
sns.countplot(x = ' Marital Status', hue = ' How much money could you spend on an Electronic vehicle?',  data = df, palette = 'Set3')
plt.legend(loc='center right')
plt.show()

# %%
df.describe()
# Out:
#               Age   No. of Family members   Annual Income  \
# count  117.000000              117.000000    1.170000e+02
# mean    36.615385                2.846154    1.846581e+06
# std      8.733453                1.330124    1.505074e+06
# min     22.000000                1.000000    0.000000e+00
# 25%     29.000000                2.000000    8.000000e+05
# 50%     35.000000                3.000000    1.500000e+06
# 75%     43.000000                4.000000    2.500000e+06
# max     56.000000                7.000000    1.000000e+07
#
#         How much money could you spend on an Electronic vehicle?  \
# count                                       1.150000e+02
# mean                                        2.596783e+06
# std                                         1.934880e+06
# min                                         3.000000e+04
# 25%                                         1.000000e+06
# 50%                                         2.000000e+06
# 75%                                         4.000000e+06
# max                                         1.000000e+07
#
#         Preference for wheels in EV
# count                    116.000000
# mean                       3.793103
# std                        0.611729
# min                        2.000000
# 25%                        4.000000
# 50%                        4.000000
# 75%                        4.000000
# max                        4.000000

# %%
plt.xlabel('Age')
plt.ylabel(' Annual Income')
plt.scatter(df['Age'],df[' Annual Income'])

# %%
plt.figure(figsize=(20,6))
sns.countplot(x="Age", data=df, hue=" Education")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=" Which brand of vehicle do you currently own?", data=df, hue=" Education")
# Out:
# <AxesSubplot:xlabel=' Which brand of vehicle do you currently own?', ylabel='count'>

# %%
plt.xlabel('Age')
plt.ylabel(' Preference for wheels in EV')
plt.scatter(df['Age'],df[' Preference for wheels in EV'])

# %%
# Heatmap of Correlation
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder
def label_encode(data,column):
        label_encoder=LabelEncoder()
        return label_encoder.fit_transform(data[column].astype(str))

# %%
df[' City']= label_encode(df,' City')
df[' Profession']= label_encode(df,' Profession')



df[' Marital Status']= label_encode(df,' Marital Status')
df[' Education']= label_encode(df,' Education')
df[' Would you prefer replacing all your vehicles to Electronic vehicles?']= label_encode(df,' Would you prefer replacing all your vehicles to Electronic vehicles?')
df[' If Yes/Maybe what type of EV would you prefer?']= label_encode(df,' If Yes/Maybe what type of EV would you prefer?')
df[' Do you think Electronic Vehicles are economical?']= label_encode(df,' Do you think Electronic Vehicles are economical?')
df[' Which brand of vehicle do you currently own?']= label_encode(df,' Which brand of vehicle do you currently own?')
df[' Do you think Electronic vehicles will replace fuel cars in India?']= label_encode(df,' Do you think Electronic vehicles will replace fuel cars in India?')
df[' How much money could you spend on an Electronic vehicle?']= label_encode(df,' How much money could you spend on an Electronic vehicle?')

# %%
df[' Annual Income']= label_encode(df,' Annual Income')

# %%
df.head()
# Out:
#    Age   City   Profession   Marital Status   Education  \
# 0   29      7            7                1           9
# 1   45      3            1                0          11
# 2   33      0            6                1           0
# 3   41      6           13                0           7
# 4   37      4           23                0           0
#
#     No. of Family members   Annual Income  \
# 0                       2              19
# 1                       4               5
# 2                       1              18
# 3                       3               6
# 4                       4               1
#
#     Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#     If Yes/Maybe what type of EV would you prefer?  \
# 0                                                3
# 1                                                1
# 2                                                0
# 3                                                4
# 4                                                1
#
#     Do you think Electronic Vehicles are economical?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#     Which brand of vehicle do you currently own?  \
# 0                                             13
# 1                                              7
# 2                                             15
# 3                                             14
# 4                                              4
#
#     How much money could you spend on an Electronic vehicle?  \
# 0                                                  4
# 1                                                  0
# 2                                                 11
# 3                                                  7
# 4                                                 13
#
#     Preference for wheels in EV  \
# 0                           4.0
# 1                           4.0
# 2                           2.0
# 3                           4.0
# 4                           4.0
#
#     Do you think Electronic vehicles will replace fuel cars in India?
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2

# %%
df.to_csv('data1.csv',index=False)

# %%
df=pd.read_csv('data1.csv')

# %%
df.columns
# Out:
# Index(['Age', ' Profession', ' Marital Status', ' Education',
#        ' No. of Family members', ' Annual Income',
#        ' Would you prefer replacing all your vehicles to Electronic vehicles?',
#        ' If Yes/Maybe what type of EV would you prefer?',
#        ' Do you think Electronic Vehicles are economical?',
#        ' Which brand of vehicle do you currently own?',
#        ' How much money could you spend on an Electronic vehicle?',
#        ' Preference for wheels in EV',
#        ' Do you think Electronic vehicles will replace fuel cars in India?'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
y = df[' City']
X = df.drop([' City'],axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\CODING\anaconda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File d:\CODING\anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\CODING\anaconda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\WORD\Feynn Labs\EV market\EV_market_segment.ipynb Cell 31 in 2
#       <a href='vscode-notebook-cell:/d%3A/WORD/Feynn%20Labs/EV%20market/EV_market_segment.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> from statsmodels.stats.outliers_influence import variance_inflation_factor
# ----> <a href='vscode-notebook-cell:/d%3A/WORD/Feynn%20Labs/EV%20market/EV_market_segment.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> y = df[' City']
#       <a href='vscode-notebook-cell:/d%3A/WORD/Feynn%20Labs/EV%20market/EV_market_segment.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a> X = df.drop([' City'],axis=1,inplace = True)
#
# File d:\CODING\anaconda\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File d:\CODING\anaconda\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ' City'

# %%
X = df.iloc[:,:-1]

# %%
X
# Out:
#      Age   Profession   Marital Status   Education   No. of Family members  \
# 0     29            7                1           9                       2
# 1     45            1                0          11                       4
# 2     33            6                1           0                       1
# 3     41           13                0           7                       3
# 4     37           23                0           0                       4
# ..   ...          ...              ...         ...                     ...
# 112   39           23                0           2                       2
# 113   46            6                0          12                       4
# 114   26            7                1           2                       1
# 115   37            1                0          12                       3
# 116   29           20                1           2                       1
#
#       Annual Income  \
# 0                19
# 1                 5
# 2                18
# 3                 6
# 4                 1
# ..              ...
# 112              19
# 113               7
# 114              17
# 115               5
# 116              18
#
#       Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 112                                                  2
# 113                                                  2
# 114                                                  2
# 115                                                  2
# 116                                                  2
#
#       If Yes/Maybe what type of EV would you prefer?  \
# 0                                                  3
# 1                                                  1
# 2                                                  0
# 3                                                  4
# 4                                                  1
# ..                                               ...
# 112                                                1
# 113                                                3
# 114                                                1
# 115                                                2
# 116                                                1
#
#       Do you think Electronic Vehicles are economical?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 112                                                  2
# 113                                                  2
# 114                                                  2
# 115                                                  2
# 116                                                  2
#
#       Which brand of vehicle do you currently own?  \
# 0                                               13
# 1                                                7
# 2                                               15
# 3                                               14
# 4                                                4
# ..                                             ...
# 112                                              8
# 113                                             14
# 114                                             12
# 115                                              3
# 116                                              8
#
#       How much money could you spend on an Electronic vehicle?  \
# 0                                                    4
# 1                                                    0
# 2                                                   11
# 3                                                    7
# 4                                                   13
# ..                                                 ...
# 112                                                  2
# 113                                                  7
# 114                                                  0
# 115                                                  5
# 116                                                  0
#
#       Preference for wheels in EV
# 0                             4.0
# 1                             4.0
# 2                             2.0
# 3                             4.0
# 4                             4.0
# ..                            ...
# 112                           4.0
# 113                           4.0
# 114                           4.0
# 115                           4.0
# 116                           4.0
#
# [117 rows x 12 columns]

# %%
X.isna
# Out:
# <bound method DataFrame.isna of      Age   Profession   Marital Status   Education   No. of Family members  \
# 0     29           21                1          12                       2
# 1     45            1                0           3                       4
# 2     33           20                1           0                       1
# 3     41            5                0          10                       3
# 4     37           16                0           0                       4
# ..   ...          ...              ...         ...                     ...
# 112   39           16                0           5                       2
# 113   46           20                0           4                       4
# 114   26           21                1           5                       1
# 115   37            1                0           4                       3
# 116   29           13                1           5                       1
#
#       Annual Income  \
# 0                19
# 1                 5
# 2                18
# 3                 6
# 4                 1
# ..              ...
# 112              19
# 113               7
# 114              17
# 115               5
# 116              18
#
#       Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    1
# 4                                                    2
# ..                                                 ...
# 112                                                  2
# 113                                                  2
# 114                                                  2
# 115                                                  2
# 116                                                  2
#
#       If Yes/Maybe what type of EV would you prefer?  \
# 0                                                  4
# 1                                                  1
# 2                                                  0
# 3                                                  5
# 4                                                  1
# ..                                               ...
# 112                                                1
# 113                                                4
# 114                                                1
# 115                                                3
# 116                                                1
#
#       Do you think Electronic Vehicles are economical?  \
# 0                                                    2
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    2
# ..                                                 ...
# 112                                                  2
# 113                                                  2
# 114                                                  2
# 115                                                  2
# 116                                                  2
#
#       Which brand of vehicle do you currently own?  \
# 0                                               14
# 1                                                7
# 2                                               16
# 3                                               15
# 4                                                4
# ..                                             ...
# 112                                              8
# 113                                             15
# 114                                             13
# 115                                              3
# 116                                              8
#
#       How much money could you spend on an Electronic vehicle?  \
# 0                                                    4
# 1                                                    0
# 2                                                   11
# 3                                                    7
# 4                                                   13
# ..                                                 ...
# 112                                                  2
# 113                                                  7
# 114                                                  0
# 115                                                  5
# 116                                                  0
#
#      Preference for wheels in EV
# 0                              4
# 1                              4
# 2                              2
# 3                              4
# 4                              4
# ..                           ...
# 112                            4
# 113                            4
# 114                            4
# 115                            4
# 116                            4
#
# [117 rows x 12 columns]>

# %%
df[' Preference for wheels in EV'].replace(to_replace = 'N/A', value = df[' Preference for wheels in EV'].mode()[0], inplace = True)

# %%
df.head(10)
# Out:
#    Age   Profession   Marital Status   Education   No. of Family members  \
# 0   29            7                1           9                       2
# 1   45            1                0          11                       4
# 2   33            6                1           0                       1
# 3   41           13                0           7                       3
# 4   37           23                0           0                       4
# 5   50            7                0          11                       3
# 6   25           22                1           3                       1
# 7   32            6                0           9                       2
# 8   46            1                0           7                       5
# 9   38            7                0           9                       3
#
#     Annual Income  \
# 0              19
# 1               5
# 2              18
# 3               6
# 4               1
# 5               9
# 6               0
# 7               3
# 8              14
# 9               6
#
#     Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  2
# 8                                                  2
# 9                                                  2
#
#     If Yes/Maybe what type of EV would you prefer?  \
# 0                                                3
# 1                                                1
# 2                                                0
# 3                                                4
# 4                                                1
# 5                                                3
# 6                                                0
# 7                                                2
# 8                                                2
# 9                                                3
#
#     Do you think Electronic Vehicles are economical?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  2
# 8                                                  2
# 9                                                  2
#
#     Which brand of vehicle do you currently own?  \
# 0                                             13
# 1                                              7
# 2                                             15
# 3                                             14
# 4                                              4
# 5                                              3
# 6                                             15
# 7                                             14
# 8                                              2
# 9                                              9
#
#     How much money could you spend on an Electronic vehicle?  \
# 0                                                  4
# 1                                                  0
# 2                                                 11
# 3                                                  7
# 4                                                 13
# 5                                                  4
# 6                                                 11
# 7                                                  9
# 8                                                 12
# 9                                                 12
#
#     Preference for wheels in EV  \
# 0                           4.0
# 1                           4.0
# 2                           2.0
# 3                           4.0
# 4                           4.0
# 5                           4.0
# 6                           2.0
# 7                           4.0
# 8                           4.0
# 9                           4.0
#
#     Do you think Electronic vehicles will replace fuel cars in India?
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  2
# 8                                                  2
# 9                                                  2

# %%
X=df.iloc[:,:-1]
X
np.any(np.isnan(X))
# Out:
# True

# %%
np.all(np.isfinite(X))
# Out:
# False

# %%
X.to_csv('data.csv')

# %%
X=pd.read_csv('data.csv')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 13 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Unnamed: 0                                                             117 non-null    int64
#  1   Age                                                                    117 non-null    int64
#  2    Profession                                                            117 non-null    int64
#  3    Marital Status                                                        117 non-null    int64
#  4    Education                                                             117 non-null    int64
#  5    No. of Family members                                                 117 non-null    int64
#  6    Annual Income                                                         117 non-null    int64
#  7    Would you prefer replacing all your vehicles to Electronic vehicles?  117 non-null    int64
#  8    If Yes/Maybe what type of EV would you prefer?                        117 non-null    int64
#  9    Do you think Electronic Vehicles are economical?                      117 non-null    int64
#  10   Which brand of vehicle do you currently own?                          117 non-null    int64
#  11   How much money could you spend on an Electronic vehicle?              117 non-null    int64
#  12   Preference for wheels in EV                                           117 non-null    int64
# dtypes: int64(13)
# memory usage: 12.0 KB

# %%
X.tail()
# Out:
#      Age   Profession   Marital Status   Education   No. of Family members  \
# 112   39           23                0           2                       2
# 113   46            6                0          12                       4
# 114   26            7                1           2                       1
# 115   37            1                0          12                       3
# 116   29           20                1           2                       1
#
#       Annual Income  \
# 112              19
# 113               7
# 114              17
# 115               5
# 116              18
#
#       Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 112                                                  2
# 113                                                  2
# 114                                                  2
# 115                                                  2
# 116                                                  2
#
#       If Yes/Maybe what type of EV would you prefer?  \
# 112                                                1
# 113                                                3
# 114                                                1
# 115                                                2
# 116                                                1
#
#       Do you think Electronic Vehicles are economical?  \
# 112                                                  2
# 113                                                  2
# 114                                                  2
# 115                                                  2
# 116                                                  2
#
#       Which brand of vehicle do you currently own?  \
# 112                                              8
# 113                                             14
# 114                                             12
# 115                                              3
# 116                                              8
#
#       How much money could you spend on an Electronic vehicle?  \
# 112                                                  2
# 113                                                  7
# 114                                                  0
# 115                                                  5
# 116                                                  0
#
#       Preference for wheels in EV
# 112                           4.0
# 113                           4.0
# 114                           4.0
# 115                           4.0
# 116                           4.0

# %%
from sklearn.cluster import KMeans
wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init="k-means++",random_state=28)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()
# Out:
# d:\CODING\anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
km = KMeans(n_clusters=4, random_state=28)
clusters = km.fit_predict(df)
df["Cluster"] = clusters

dataset["Cluster"] = clusters

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.Age[df.Cluster == 0], df[" Annual Income"][df.Cluster == 0], df[" How much money could you spend on an Electronic vehicle?"][df.Cluster == 0], c='blue', s=60)
ax.scatter(df.Age[df.Cluster == 1], df[" Annual Income"][df.Cluster == 1], df[" How much money could you spend on an Electronic vehicle?"][df.Cluster == 1], c='red', s=60)
ax.scatter(df.Age[df.Cluster == 2], df[" Annual Income"][df.Cluster == 2], df[" How much money could you spend on an Electronic vehicle?"][df.Cluster == 2], c='green', s=60)
ax.scatter(df.Age[df.Cluster == 3], df[" Annual Income"][df.Cluster == 3], df[" How much money could you spend on an Electronic vehicle?"][df.Cluster == 3], c='orange', s=60)

ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel(" Annual Income")
ax.set_zlabel(' How much money could you spend on an Electronic vehicle?')
plt.show()

# %%
df.head()
# Out:
#    Age   Profession   Marital Status   Education   No. of Family members  \
# 0   29            7                1           9                       2
# 1   45            1                0          11                       4
# 2   33            6                1           0                       1
# 3   41           13                0           7                       3
# 4   37           23                0           0                       4
#
#     Annual Income  \
# 0              19
# 1               5
# 2              18
# 3               6
# 4               1
#
#     Would you prefer replacing all your vehicles to Electronic vehicles?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#     If Yes/Maybe what type of EV would you prefer?  \
# 0                                                3
# 1                                                1
# 2                                                0
# 3                                                4
# 4                                                1
#
#     Do you think Electronic Vehicles are economical?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#     Which brand of vehicle do you currently own?  \
# 0                                             13
# 1                                              7
# 2                                             15
# 3                                             14
# 4                                              4
#
#     How much money could you spend on an Electronic vehicle?  \
# 0                                                  4
# 1                                                  0
# 2                                                 11
# 3                                                  7
# 4                                                 13
#
#     Preference for wheels in EV  \
# 0                             4
# 1                             4
# 2                             2
# 3                             4
# 4                             4
#
#     Do you think Electronic vehicles will replace fuel cars in India?  Cluster
# 0                                                  2                         1
# 1                                                  2                         3
# 2                                                  2                         1
# 3                                                  1                         3
# 4                                                  2                         2

# %%
dataset['Cluster'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Cluster'].value_counts()
# Out:
# 3    44
# 1    31
# 0    23
# 2    19
# Name: Cluster, dtype: int64

# %% [markdown]
# <b>More Clusters belong to clusters 3 and 1.</b><br>
# Clusters 0 and 2 have very less customers.

# %%
# Segregrating each cluster

Cluster_0 = dataset[dataset.Cluster==0]
Cluster_1 = dataset[dataset.Cluster==1]
Cluster_2 = dataset[dataset.Cluster==2]
Cluster_3 = dataset[dataset.Cluster==3]
Cluster_3.shape
# Out:
# (44, 15)

# %%
[Cluster_0['Age'].value_counts().head(3), 
 Cluster_1['Age'].value_counts().head(3), 
 Cluster_2['Age'].value_counts().head(3), 
 Cluster_3['Age'].value_counts().head(3)]
# Out:
# [50    7
#  49    3
#  46    2
#  Name: Age, dtype: int64,
#  26    7
#  28    6
#  29    4
#  Name: Age, dtype: int64,
#  30    3
#  36    2
#  35    2
#  Name: Age, dtype: int64,
#  35    4
#  42    4
#  37    4
#  Name: Age, dtype: int64]

# %% [markdown]
# <b>Based on Cluster 3 and 1 age group of 26 to 43 should be targeted.</b>

# %%
[Cluster_0[' City'].value_counts().head(),
 Cluster_1[' City'].value_counts().head(), 
 Cluster_2[' City'].value_counts().head(), 
 Cluster_3[' City'].value_counts().head()]
# Out:
# [Hyderabad    10
#  Mumbai        4
#  Chennai       3
#  Delhi         2
#  Kolkata       2
#  Name:  City, dtype: int64,
#  Bangalore    12
#  Mumbai       10
#  Kolkata       4
#  Hyderabad     2
#  Chennai       1
#  Name:  City, dtype: int64,
#  Bangalore    6
#  Kolkata      4
#  Hyderabad    2
#  Delhi        2
#  Mumbai       2
#  Name:  City, dtype: int64,
#  Delhi        17
#  Mumbai        8
#  Chennai       7
#  Hyderabad     5
#  Kolkata       3
#  Name:  City, dtype: int64]

# %% [markdown]
# <h2><b>Mumbai and Hyderabad</b> are the most suitabe location for early market in EV. </h2><br>
# <h3><b>Kolkata</b> should be the next Priority.</h3><br>
# <b>Delhi, Chennai, Bangalore</b> should follow next.

# %%
[Cluster_0[' Profession'].value_counts().head(), 
 Cluster_1[' Profession'].value_counts().head(), 
 Cluster_2[' Profession'].value_counts().head(), 
 Cluster_3[' Profession'].value_counts().head()]
# Out:
# [Businessman     10
#  Engineer         2
#  Doctor           2
#  Entrepreneur     2
#  Lawyer           2
#  Name:  Profession, dtype: int64,
#  Engineer               7
#  Software Developer     5
#  Doctor                 3
#  Architect              2
#  Marketing Executive    2
#  Name:  Profession, dtype: int64,
#  Teacher               6
#  Software Developer    6
#  Student               3
#  Software Engineer     2
#  Manager               1
#  Name:  Profession, dtype: int64,
#  Doctor         12
#  Engineer        9
#  Manager         5
#  Businessman     4
#  Architect       4
#  Name:  Profession, dtype: int64]

# %% [markdown]
# <h3><b>Engineers</b> are the most interested in EV.</h3>
# Followed by <b>Doctors and Businessman</b>.

# %%
[Cluster_0[' Annual Income'].mean(), 
 Cluster_1[' Annual Income'].mean(), 
 Cluster_2[' Annual Income'].mean(), 
 Cluster_3[' Annual Income'].mean()]
# Out:
# [4282608.695652174, 729032.2580645161, 1013157.8947368421, 1720454.5454545454]

# %% [markdown]
# <h3><b> Cluster 0</b> customers have higher average income.</h3>
# <b>Cluster 1 and 2</b> customers have lower average income.

# %%
[Cluster_0[' Marital Status'].value_counts().head(), 
 Cluster_1[' Marital Status'].value_counts().head(), 
 Cluster_2[' Marital Status'].value_counts().head(), 
 Cluster_3[' Marital Status'].value_counts().head()]
# Out:
# [Married    23
#  Name:  Marital Status, dtype: int64,
#  Single     27
#  Married     4
#  Name:  Marital Status, dtype: int64,
#  Single     10
#  Married     9
#  Name:  Marital Status, dtype: int64,
#  Married    39
#  Single      5
#  Name:  Marital Status, dtype: int64]

# %%
m=Cluster_3[Cluster_3[' Marital Status']=='Married']
m[' Would you prefer replacing all your vehicles to Electronic vehicles?'].value_counts()
# Out:
# Yes      27
# No       10
# Maybe     2
# Name:  Would you prefer replacing all your vehicles to Electronic vehicles?, dtype: int64

# %% [markdown]
# <b>Married people</b> should be targeted.

# %%
[Cluster_0[' No. of Family members'].value_counts().head(), 
 Cluster_1[' No. of Family members'].value_counts().head(), 
 Cluster_2[' No. of Family members'].value_counts().head(), 
 Cluster_3[' No. of Family members'].value_counts().head()]
# Out:
# [5    9
#  4    8
#  3    2
#  2    2
#  7    1
#  Name:  No. of Family members, dtype: int64,
#  2    16
#  1    14
#  3     1
#  Name:  No. of Family members, dtype: int64,
#  4    5
#  1    5
#  2    5
#  3    4
#  Name:  No. of Family members, dtype: int64,
#  3    18
#  4    15
#  2     8
#  1     2
#  5     1
#  Name:  No. of Family members, dtype: int64]

# %% [markdown]
# Family with <b>3 - 5 </b>members are interested in EV.

# %%
[Cluster_0[' Which brand of vehicle do you currently own?'].value_counts().head(), 
 Cluster_1[' Which brand of vehicle do you currently own?'].value_counts().head(), 
 Cluster_2[' Which brand of vehicle do you currently own?'].value_counts().head(), 
 Cluster_3[' Which brand of vehicle do you currently own?'].value_counts().head()]
# Out:
# [Ford             5
#  Audi             5
#  BMW              4
#  Tata             2
#  Mercedes-Benz    2
#  Name:  Which brand of vehicle do you currently own?, dtype: int64,
#  Hyundai          5
#  Tata             5
#  Maruti           4
#  Honda            4
#  Maruti Suzuki    4
#  Name:  Which brand of vehicle do you currently own?, dtype: int64,
#  Hyundai    5
#  Maruti     3
#  Tata       3
#  Toyota     2
#  Kia        1
#  Name:  Which brand of vehicle do you currently own?, dtype: int64,
#  Toyota    13
#  Honda      8
#  Maruti     5
#  Tesla      5
#  Tata       4
#  Name:  Which brand of vehicle do you currently own?, dtype: int64]

# %% [markdown]
# <b>Tata, Maruti, Hyundai and Toyota</b> are the brands which people own the most.

# %%
[Cluster_0[' Education'].value_counts().head(),
 Cluster_1[' Education'].value_counts().head(), 
 Cluster_2[' Education'].value_counts().head(), 
 Cluster_3[' Education'].value_counts().head()]
# Out:
# [Bachelor's degree    7
#  MBA                  5
#  PhD                  2
#  Doctorate degree     2
#  Postgraduate         2
#  Name:  Education, dtype: int64,
#  Bachelor's degree    18
#  Graduate              5
#  Master's degree       4
#  MBA                   3
#  Masters Degree        1
#  Name:  Education, dtype: int64,
#  Bachelor's degree    10
#  High School           3
#  Graduate              2
#  Masters Degree        2
#  MBA                   1
#  Name:  Education, dtype: int64,
#  Master's degree      12
#  Bachelor's degree     7
#  MBA                   5
#  Postgraduate          5
#  Doctorate degree      3
#  Name:  Education, dtype: int64]

# %% [markdown]
# People with <b>Bachelor's Degree</b> are most interested in EV

# %%
e=Cluster_3[Cluster_3[' Education']=="Bachelor's degree"]
e[' Would you prefer replacing all your vehicles to Electronic vehicles?'].value_counts()
# Out:
# Yes    5
# No     2
# Name:  Would you prefer replacing all your vehicles to Electronic vehicles?, dtype: int64

# %%
y= dataset[' Would you prefer replacing all your vehicles to Electronic vehicles?']
z=dataset['Cluster']
x = list(zip(y, z))

i = pd.DataFrame(x,columns=[' Would you prefer replacing all your vehicles to Electronic vehicles?', 'Cluster'])
(i[' Would you prefer replacing all your vehicles to Electronic vehicles?']=='Yes').sum() + (i[' Would you prefer replacing all your vehicles to Electronic vehicles?']=='Maybe').sum()
# Out:
# 92

# %% [markdown]
# <b>92 out of 117</b> i.e. nearly <b>78.6324% </b>of poeple are interestedin EV.

# %%
print(Cluster_0[' If Yes/Maybe what type of EV would you prefer?'].value_counts().head(3))
print(Cluster_1[' If Yes/Maybe what type of EV would you prefer?'].value_counts().head(3))
print(Cluster_2[' If Yes/Maybe what type of EV would you prefer?'].value_counts().head(3))
print(Cluster_3[' If Yes/Maybe what type of EV would you prefer?'].value_counts().head(3))
# Out:
# Sedan        11
# SUV           8
# Hatchback     1
# Name:  If Yes/Maybe what type of EV would you prefer?, dtype: int64
# Hatchback    14
# Sedan         3
# SUV           3
# Name:  If Yes/Maybe what type of EV would you prefer?, dtype: int64
# Hatchback           7
# SUV                 4
# Electric Scooter    3
# Name:  If Yes/Maybe what type of EV would you prefer?, dtype: int64
# Sedan        13
# SUV          10
# Hatchback     9
# Name:  If Yes/Maybe what type of EV would you prefer?, dtype: int64

# %% [markdown]
# People are more interested in buying <b>Sedan</b>, followed by <b>SUV</b> and <b>Hatchback</b>.

# %%
print(Cluster_0[' How much money could you spend on an Electronic vehicle?'].value_counts().head())
print(Cluster_1[' How much money could you spend on an Electronic vehicle?'].value_counts().head())
print(Cluster_2[' How much money could you spend on an Electronic vehicle?'].value_counts().head())
print(Cluster_3[' How much money could you spend on an Electronic vehicle?'].value_counts().head())
# Out:
# 4000000.0     7
# 5000000.0     4
# 6000000.0     4
# 2000000.0     2
# 10000000.0    2
# Name:  How much money could you spend on an Electronic vehicle?, dtype: int64
# 1000000.0    10
# 800000.0      5
# 2000000.0     3
# 1500000.0     3
# 2500000.0     2
# Name:  How much money could you spend on an Electronic vehicle?, dtype: int64
# 2000000.0    4
# 50000.0      3
# 600000.0     2
# 800000.0     2
# 1500000.0    2
# Name:  How much money could you spend on an Electronic vehicle?, dtype: int64
# 2000000.0    10
# 3000000.0     6
# 2500000.0     6
# 4000000.0     5
# 5000000.0     5
# Name:  How much money could you spend on an Electronic vehicle?, dtype: int64

# %% [markdown]
# Considering only Cluster 3 & 1:<br>
# 10/32 and 16/23 i.e. <b>31.25%</b> and <b>69.565%</b> of customers are willing to pay between <b>10Lakhs and 20 Lakhs</b> for EV.

# %% [markdown]
# Thus the company should focus on building <b>Sedan</b> in the price range of <b>10 to 20 lakhs</b> for most impactful marketing.

# %% [markdown]
# <h2>Demographic segments:</h2>

# %% [markdown]
# <h4>Age:</h4>
# Target age group 26-43.

# %% [markdown]
# <h4>Income:</h4>
# Tagret cdustomers who earn >= 1720454.5454545454 per anum.

# %% [markdown]
# <h4>Education:</h4>
# Target Bachelor's Degree (Graduates).

# %% [markdown]
# <h2>Geographic segments:</h2>

# %% [markdown]
# <h4>Location:</h4>
# Target location Mumbai, Hyderabad, Kolkata, Delhi, Chennai and Bangalore.

# %% [markdown]
# <h2>Psychographic segments:</h2>

# %% [markdown]
# <h4>Lifestyle:</h4>
# Target Married customers with no. of family members: 3-5.
